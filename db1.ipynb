# %%
import pandas as pd

# %%
df=pd.read_excel("Metrics.xlsx")
df
# Out:
#     country_id      Country                                   Category  \
# 0            1  Ivory Coast                        Economic indicators
# 1            1  Ivory Coast                        Economic indicators
# 2            1  Ivory Coast                        Economic indicators
# 3            1  Ivory Coast                        Economic indicators
# 4            1  Ivory Coast                        Economic indicators
# 5            1  Ivory Coast                        Economic indicators
# 6            1  Ivory Coast                          Social indicators
# 7            1  Ivory Coast                          Social indicators
# 8            1  Ivory Coast                          Social indicators
# 9            1  Ivory Coast                          Social indicators
# 10           1  Ivory Coast                          Social indicators
# 11           1  Ivory Coast                          Social indicators
# ...

# %%
import pandas as pd
import pymysql.cursors
import json
## OFIS PRD

connection = pymysql.connect(host='172.29.16.21',user='cubuntu',
                             password='cluster321',                             
                             charset='utf8mb4',
                             database='FarmsPosition',
                             cursorclass=pymysql.cursors.DictCursor
                            )


## writing DF to sql DB
# sql_data.to_sql(con=connection, name='farms_pos1', if_exists='append', flavor='mysql')

# %%
c1 = connection.cursor()
c1.execute("show tables")
# row = cursor.fetchall()
for row in c1:
    print(row)
# Out:
# {'Tables_in_FarmsPosition': 'Metrics'}
# {'Tables_in_FarmsPosition': 'farms_pos1'}
# {'Tables_in_FarmsPosition': 'satelliteDb'}

# %%
cursor = connection.cursor()
# c1.execute('SELECT * FROM persons')
c1=cursor.execute("select * from farms_pos1")
c1
# for i in c1:
#     print(i,)
# Out:
# 0

# %%
df1=df
# sql_data=df1
# sql_data.to_sql(con=connection, name='Metrics', if_exists='append')
# sql_data.to_sql(con=connection, name='Metrics', if_exists='append')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://cubuntu:cluster321@172.29.16.21/FarmsPosition')

# df1.to_sql("Metrics", con = engine)  # excecute once and put in comment

# %%
cursor = connection.cursor()
cursor.execute("show tables")
# row = cursor.fetchall()
for row in cursor:
    print(row)
# Out:
# {'Tables_in_FarmsPosition': 'Metrics'}
# {'Tables_in_FarmsPosition': 'farms_pos1'}
# {'Tables_in_FarmsPosition': 'satelliteDb'}

# %%
# c1 = connection.cursor()
cursor.execute('SELECT * FROM Metrics')
for row in cursor:
    print('row = %r' % (row,))

# conn.close()
# Out:
# row = {'index': 0, 'country_id': 1, 'Country': 'Ivory Coast', 'Category': 'Economic indicators', 'Index Name': 'GDP growth rate', 'year': 2005, 'Values': 1.7, 'unit': '%'}
# row = {'index': 1, 'country_id': 1, 'Country': 'Ivory Coast', 'Category': 'Economic indicators', 'Index Name': 'Agriculture\xa0(% of Gross Value Added)', 'year': 2005, 'Values': 24.3, 'unit': '%'}
# row = {'index': 2, 'country_id': 1, 'Country': 'Ivory Coast', 'Category': 'Economic indicators', 'Index Name': 'Employment in agriculture\xa0(% of employed)', 'year': 2005, 'Values': 50.6, 'unit': '%'}
# row = {'index': 3, 'country_id': 1, 'Country': 'Ivory Coast', 'Category': 'Economic indicators', 'Index Name': 'Female Labour force participation rate\xa0(pop. %)', 'year': 2005, 'Values': 48.3, 'unit': '%'}
# row = {'index': 4, 'country_id': 1, 'Country': 'Ivory Coast', 'Category': 'Economic indicators', 'Index Name': 'International Trade Exports(million)', 'year': 2005, 'Values': 7248.0, 'unit': 'million $'}
# ...

# %%
df2=pd.read_excel("satellite db2.xlsx")
df2
# df2.to_sql("satelliteDb", con = engine)   # excecute once and put in comment
# Out:
#     country_id      Country  region_id Region  farmergroup_id Farmer group  \
# 0            1  Ivory Coast          1   NORD               1      COOPYCA
# 1            1  Ivory Coast          1   NORD               1      COOPYCA
# 2            1  Ivory Coast          1   NORD               1      COOPYCA
# 3            1  Ivory Coast          1   NORD               2     COOPROYA
# 4            1  Ivory Coast          1   NORD               2     COOPROYA
# 5            1  Ivory Coast          1   NORD               2     COOPROYA
# 6            1  Ivory Coast          1   NORD               1      COOPYCA
# 7            1  Ivory Coast          1   NORD               1      COOPYCA
# 8            1  Ivory Coast          1   NORD               1      COOPYCA
# 9            1  Ivory Coast          1   NORD               2     COOPROYA
# 10           1  Ivory Coast          1   NORD               2     COOPROYA
# ...

# %%
# c1 = connection.cursor()
cursor.execute('show tables')
for row in cursor:
    print(row)

# conn.close()
# Out:
# {'Tables_in_FarmsPosition': 'Metrics'}
# {'Tables_in_FarmsPosition': 'farms_pos1'}
# {'Tables_in_FarmsPosition': 'satelliteDb'}

# %%
c1 = connection.cursor()
cursor.execute('SELECT * FROM satelliteDb')
for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = {'index': 0, 'country_id': 1, 'Country': 'Ivory Coast', 'region_id': 1, 'Region': 'NORD', 'farmergroup_id': 1, 'Farmer group': 'COOPYCA', 'product_id': 1, 'Product': 'Cotton', 'Farm id': 1, 'Plot id': 1, 'Geojson data': '{\n  "type": "FeatureCollection",\n  "features": [\n    {\n      "type": "Feature",\n      "properties": {},\n      "geometry": {\n        "type": "Polygon",\n        "coordinates": [\n          [\n            [\n              -5.726795196533203,\n              10.006043803798357\n            ],\n            [\n              -5.727653503417969,\n              10.00435329630218\n            ],\n            [\n              -5.725765228271484,\n              10.004184245068602\n            ],\n            [\n              -5.726795196533203,\n              10.006043803798357\n            ]\n          ]\n        ]\n      }\n    }\n  ]\n}', 'Category': 'Satellite Metrics', 'Index Name': 'NDVI', 'Folder Path(Date taken is 1th Feb 2019,Farm id, plotid)': 'https://big
# ...

# %%
# c1 = connection.cursor()
# c1.execute("drop table satelliteDb")

# %%
cursor.execute('show tables')
for row in cursor:
    print(row)
# Out:
# {'Tables_in_FarmsPosition': 'Metrics'}
# {'Tables_in_FarmsPosition': 'farms_pos1'}
# {'Tables_in_FarmsPosition': 'satelliteDb'}
